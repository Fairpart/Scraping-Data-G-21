# %% [markdown]
# ### สร้าง var ขึ้นรองรับข้อมูล และ import ไลบารี่สำคัญ และ นำเข้า link เว็บไซต์

# %%
# Use List
Name_list = list()
Price_Per_Night_list = list()
Total_Price_list = list()
Rates_list = list()
Star_list = list()
Num_reviewer = list()
new_Num_reviewer = list()

# %%
from bs4 import BeautifulSoup
import requests

urls = ['https://th.airbnb.com/s/BTS-~-PHAYATHAI--Samsen-Nai--Phaya-Thai--Bangkok--Thailand/homes?adults=2&refinement_paths%5B%5D=%2Fhomes&tab_id=home_tab&flexible_trip_lengths%5B%5D=one_week&price_filter_input_type=0&price_filter_num_nights=4&search_type=filter_change&room_types%5B%5D=Private%20room&l2_property_type_ids%5B%5D=1&l2_property_type_ids%5B%5D=3&l2_property_type_ids%5B%5D=4&amenities%5B%5D=4&amenities%5B%5D=5&date_picker_type=calendar&source=structured_search_input_header&min_bedrooms=1&min_beds=1&min_bathrooms=1&superhost=true&checkin=2023-04-12&checkout=2023-04-16&query=BTS%20-%20PHAYATHAI%2C%20Samsen%20Nai%2C%20Phaya%20Thai%2C%20Bangkok&place_id=ChIJN6hNkx2c4jARyNY0OlyXh84&ne_lat=13.78177222948684&ne_lng=100.57352989270504&sw_lat=13.746814142447073&sw_lng=100.52343337911799&zoom=14&search_by_map=true&federated_search_session_id=0afaa6f6-4f5b-402f-a27e-a3bee0644cc3&pagination_search=true&items_offset=20&section_offset=2&cursor=eyJzZWN0aW9uX29mZnNldCI6MCwiaXRlbXNfb2Zmc2V0IjowLCJ2ZXJzaW9uIjoxfQ%3D%3D',
'https://th.airbnb.com/s/BTS-~-PHAYATHAI--Samsen-Nai--Phaya-Thai--Bangkok--Thailand/homes?adults=2&refinement_paths%5B%5D=%2Fhomes&tab_id=home_tab&flexible_trip_lengths%5B%5D=one_week&price_filter_input_type=0&price_filter_num_nights=4&search_type=filter_change&room_types%5B%5D=Private%20room&l2_property_type_ids%5B%5D=1&l2_property_type_ids%5B%5D=3&l2_property_type_ids%5B%5D=4&amenities%5B%5D=4&amenities%5B%5D=5&date_picker_type=calendar&source=structured_search_input_header&min_bedrooms=1&min_beds=1&min_bathrooms=1&superhost=true&checkin=2023-04-12&checkout=2023-04-16&query=BTS%20-%20PHAYATHAI%2C%20Samsen%20Nai%2C%20Phaya%20Thai%2C%20Bangkok&place_id=ChIJN6hNkx2c4jARyNY0OlyXh84&ne_lat=13.78177222948684&ne_lng=100.57352989270504&sw_lat=13.746814142447073&sw_lng=100.52343337911799&zoom=14&search_by_map=true&federated_search_session_id=0afaa6f6-4f5b-402f-a27e-a3bee0644cc3&pagination_search=true&items_offset=20&section_offset=2&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoyMCwidmVyc2lvbiI6MX0%3D',
'https://th.airbnb.com/s/BTS-~-PHAYATHAI--Samsen-Nai--Phaya-Thai--Bangkok--Thailand/homes?adults=2&refinement_paths%5B%5D=%2Fhomes&tab_id=home_tab&flexible_trip_lengths%5B%5D=one_week&price_filter_input_type=0&price_filter_num_nights=4&search_type=filter_change&room_types%5B%5D=Private%20room&l2_property_type_ids%5B%5D=1&l2_property_type_ids%5B%5D=3&l2_property_type_ids%5B%5D=4&amenities%5B%5D=4&amenities%5B%5D=5&date_picker_type=calendar&source=structured_search_input_header&min_bedrooms=1&min_beds=1&min_bathrooms=1&superhost=true&checkin=2023-04-12&checkout=2023-04-16&query=BTS%20-%20PHAYATHAI%2C%20Samsen%20Nai%2C%20Phaya%20Thai%2C%20Bangkok&place_id=ChIJN6hNkx2c4jARyNY0OlyXh84&ne_lat=13.78177222948684&ne_lng=100.57352989270504&sw_lat=13.746814142447073&sw_lng=100.52343337911799&zoom=14&search_by_map=true&federated_search_session_id=0afaa6f6-4f5b-402f-a27e-a3bee0644cc3&pagination_search=true&items_offset=20&section_offset=2&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0Ijo0MCwidmVyc2lvbiI6MX0%3D'    ]

for url in urls:
    req = requests.get(url,'html.parsel')
    soup = BeautifulSoup(req.text)
    
    for n in soup.find_all('div' ,{'class' : 't1jojoys dir dir-ltr'}):
        x_n = n.text
        Name_list.append(x_n)
    for p in soup.find_all('span', {'class':'_tyxjp1'}):
        x_p = p.text.split('฿')[1]
        Price_Per_Night_list.append(x_p)
    for t in soup.find_all('div', {'class':'_tt122m'}):
        x_t = t.text.split()[1]
        x_t_1 = x_t.split('฿')[1]
        Total_Price_list.append(x_t_1)
    for r in soup.find_all('span', {'class':'t5eq1io r4a59j5 dir dir-ltr'}):
        x_r = r.text
        Rates_list.append(x_r)
for i in Rates_list:
    rate = i.split()
    if len(rate) == 2:
        Star_list.append(rate[0])
        Num_reviewer.append(rate[1])
    else:
        Star_list.append(str(0))
        Num_reviewer.append(str(0))
for i in Num_reviewer:
    new_Num_reviewer.append(i.replace('(','').replace(')',''))

# %%
print(len(Name_list))
print(len(Price_Per_Night_list))
print(len(Total_Price_list))
print(len(Rates_list))
print(len(Star_list))
print(len(Num_reviewer))
print(len(new_Num_reviewer))
# Out:
# 44
# 44
# 44
# 32
# 32
# 32
# 32

# %% [markdown]
# ### สร้าง pandas

# %%
import pandas as pd

# %%
# Save Data to Table
# บันทึก ข้อมูล ลงตาราง #ปรับให้อยู่ในรูปคอลัมน์
table = pd.DataFrame([Name_list, Price_Per_Night_list, Total_Price_list, Star_list, new_Num_reviewer]).transpose()
#ตั้งชื่อคอลัมน์
table.columns = (['Title', 'Price_a_Night','Total_Price', 'Rating','No_Reviewer'])
table
# Out:
#                                  Title Price_a_Night Total_Price Rating  \
# 0        ห้องส่วนตัวใน Khet Phaya Thai        1,427        5,706    5.0
# 1                ห้องส่วนตัวใน กรุงเทพ        1,383        6,231   4.87
# 2                ห้องส่วนตัวใน กรุงเทพ          720        3,080   4.99
# 3                ห้องส่วนตัวใน กรุงเทพ        1,733        7,130   4.91
# 4       ห้องส่วนตัวใน Khet Ratchathewi        1,617        7,018    5.0
# 5              ห้องส่วนตัวใน Din Daeng          739        3,754   4.98
# 6                ห้องส่วนตัวใน กรุงเทพ          779        3,347   4.95
# 7                  ห้องส่วนตัวใน พญาไท        1,291        5,364    5.0
# 8        ห้องส่วนตัวใน Khet Phaya Thai          720        3,080   4.93
# 9                ห้องส่วนตัวใน กรุงเทพ        1,618        6,670    4.9
# 10                 ห้องส่วนตัวใน พญาไท        1,240        5,158   4.95
# 11             ห้องส่วนตัวใน Din Daeng          733        3,732   4.93
# 12      ห้องส่วนตัวใน Khet Ratchathewi        1,277        5,706   4.91
# 13       ห้องพักในโรงแรมใน Ratchathewi        2,250        9,000      0
# 14               ห้องส่วนตัวใน กรุงเทพ        1,503        6,210   4.89
# 15  ห้องพักในโรงแรมใน Khet Ratchathewi        2,578       10,613   4.78
# 16               ห้องส่วนตัวใน กรุงเทพ        1,951        8,102      0
# 17       ห้องส่วนตัวใน Khet Pathum Wan          840        3,560   4.49
# 18      ห้องส่วนตัวใน Khet Ratchathewi        1,712        6,847    5.0
# 19    ห้องพักในโรงแรมใน Khet Din Daeng        1,095        4,380   4.86
# 20  ห้องพักในโรงแรมใน Khet Ratchathewi        2,350        9,400   4.89
# 21               ห้องส่วนตัวใน กรุงเทพ        1,277        5,706      0
# 22               ห้องส่วนตัวใน กรุงเทพ        1,277        5,706   4.51
# 23       ห้องส่วนตัวใน Khet Pathum Wan        1,070        4,478    5.0
# 24               ห้องส่วนตัวใน กรุงเทพ        1,826        7,304   4.73
# 25           ห้องพักในโรงแรมใน กรุงเทพ        2,578       10,613    4.8
# 26  ห้องพักในโรงแรมใน Khet Ratchathewi        2,578       10,613   4.75
# 27               ห้องส่วนตัวใน กรุงเทพ          444        1,977   4.94
# 28               ห้องส่วนตัวใน กรุงเทพ        1,277        5,706   4.33
# 29    ห้องพักในโรงแรมใน Khet Din Daeng        1,095        4,380   4.67
# 30      ห้องส่วนตัวใน Khet Ratchathewi        1,255        5,021    4.5
# 31  ห้องพักในโรงแรมใน Khet Ratchathewi        1,505        6,020    4.8
# 32       ห้องส่วนตัวใน Khet Phaya Thai        4,176       17,004   None
# 33        ห้องส่วนตัวใน Khet Din Daeng        1,568        6,270   None
# 34    ห้องพักในโรงแรมใน Khet Din Daeng        1,095        4,380   None
# 35      ห้องส่วนตัวใน Khet Ratchathewi        1,141        4,565   None
# 36      ห้องส่วนตัวใน Khet Ratchathewi        1,722        7,189   None
# 37        ห้องส่วนตัวใน Khet Din Daeng        2,090        8,360   None
# 38     ห้องในโรงแรมใน Khet Ratchathewi          944        3,777   None
# 39      ห้องส่วนตัวใน Khet Ratchathewi        3,081       12,325   None
# 40    ห้องพักในโรงแรมใน Khet Din Daeng        1,095        4,380   None
# 41      ห้องส่วนตัวใน Khet Ratchathewi        1,255        5,021   None
# 42     ห้องในโรงแรมใน Khet Ratchathewi          913        3,652   None
# 43               ห้องส่วนตัวใน กรุงเทพ        3,081       12,325   None
#
#    No_Reviewer
# 0           40
# 1           97
# 2           78
# 3          162
# 4            4
# 5           55
# 6           57
# 7           28
# 8           28
# 9          188
# 10          22
# 11         123
# 12          56
# 13           0
# 14         202
# 15          74
# 16           0
# 17          59
# 18           4
# 19          91
# 20          65
# 21           0
# 22          84
# 23           4
# 24          41
# 25          10
# 26          48
# 27          53
# 28           3
# 29           3
# 30           4
# 31          10
# 32        None
# 33        None
# 34        None
# 35        None
# 36        None
# 37        None
# 38        None
# 39        None
# 40        None
# 41        None
# 42        None
# 43        None

# %%
table['Rating'] = table['Rating'].fillna('None')
table['No_Reviewer'] = table['No_Reviewer'].fillna('None')

# %%
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          44 non-null     object
#  1   Price_a_Night  44 non-null     object
#  2   Total_Price    44 non-null     object
#  3   Rating         44 non-null     object
#  4   No_Reviewer    44 non-null     object
# dtypes: object(5)
# memory usage: 1.8+ KB

# %%
table
# Out:
#                                  Title Price_a_Night Total_Price Rating  \
# 0        ห้องส่วนตัวใน Khet Phaya Thai        1,427        5,706    5.0
# 1                ห้องส่วนตัวใน กรุงเทพ        1,383        6,231   4.87
# 2                ห้องส่วนตัวใน กรุงเทพ          720        3,080   4.99
# 3                ห้องส่วนตัวใน กรุงเทพ        1,733        7,130   4.91
# 4       ห้องส่วนตัวใน Khet Ratchathewi        1,617        7,018    5.0
# 5              ห้องส่วนตัวใน Din Daeng          739        3,754   4.98
# 6                ห้องส่วนตัวใน กรุงเทพ          779        3,347   4.95
# 7                  ห้องส่วนตัวใน พญาไท        1,291        5,364    5.0
# 8        ห้องส่วนตัวใน Khet Phaya Thai          720        3,080   4.93
# 9                ห้องส่วนตัวใน กรุงเทพ        1,618        6,670    4.9
# 10                 ห้องส่วนตัวใน พญาไท        1,240        5,158   4.95
# 11             ห้องส่วนตัวใน Din Daeng          733        3,732   4.93
# 12      ห้องส่วนตัวใน Khet Ratchathewi        1,277        5,706   4.91
# 13       ห้องพักในโรงแรมใน Ratchathewi        2,250        9,000      0
# 14               ห้องส่วนตัวใน กรุงเทพ        1,503        6,210   4.89
# 15  ห้องพักในโรงแรมใน Khet Ratchathewi        2,578       10,613   4.78
# 16               ห้องส่วนตัวใน กรุงเทพ        1,951        8,102      0
# 17       ห้องส่วนตัวใน Khet Pathum Wan          840        3,560   4.49
# 18      ห้องส่วนตัวใน Khet Ratchathewi        1,712        6,847    5.0
# 19    ห้องพักในโรงแรมใน Khet Din Daeng        1,095        4,380   4.86
# 20  ห้องพักในโรงแรมใน Khet Ratchathewi        2,350        9,400   4.89
# 21               ห้องส่วนตัวใน กรุงเทพ        1,277        5,706      0
# 22               ห้องส่วนตัวใน กรุงเทพ        1,277        5,706   4.51
# 23       ห้องส่วนตัวใน Khet Pathum Wan        1,070        4,478    5.0
# 24               ห้องส่วนตัวใน กรุงเทพ        1,826        7,304   4.73
# 25           ห้องพักในโรงแรมใน กรุงเทพ        2,578       10,613    4.8
# 26  ห้องพักในโรงแรมใน Khet Ratchathewi        2,578       10,613   4.75
# 27               ห้องส่วนตัวใน กรุงเทพ          444        1,977   4.94
# 28               ห้องส่วนตัวใน กรุงเทพ        1,277        5,706   4.33
# 29    ห้องพักในโรงแรมใน Khet Din Daeng        1,095        4,380   4.67
# 30      ห้องส่วนตัวใน Khet Ratchathewi        1,255        5,021    4.5
# 31  ห้องพักในโรงแรมใน Khet Ratchathewi        1,505        6,020    4.8
# 32       ห้องส่วนตัวใน Khet Phaya Thai        4,176       17,004   None
# 33        ห้องส่วนตัวใน Khet Din Daeng        1,568        6,270   None
# 34    ห้องพักในโรงแรมใน Khet Din Daeng        1,095        4,380   None
# 35      ห้องส่วนตัวใน Khet Ratchathewi        1,141        4,565   None
# 36      ห้องส่วนตัวใน Khet Ratchathewi        1,722        7,189   None
# 37        ห้องส่วนตัวใน Khet Din Daeng        2,090        8,360   None
# 38     ห้องในโรงแรมใน Khet Ratchathewi          944        3,777   None
# 39      ห้องส่วนตัวใน Khet Ratchathewi        3,081       12,325   None
# 40    ห้องพักในโรงแรมใน Khet Din Daeng        1,095        4,380   None
# 41      ห้องส่วนตัวใน Khet Ratchathewi        1,255        5,021   None
# 42     ห้องในโรงแรมใน Khet Ratchathewi          913        3,652   None
# 43               ห้องส่วนตัวใน กรุงเทพ        3,081       12,325   None
#
#    No_Reviewer
# 0           40
# 1           97
# 2           78
# 3          162
# 4            4
# 5           55
# 6           57
# 7           28
# 8           28
# 9          188
# 10          22
# 11         123
# 12          56
# 13           0
# 14         202
# 15          74
# 16           0
# 17          59
# 18           4
# 19          91
# 20          65
# 21           0
# 22          84
# 23           4
# 24          41
# 25          10
# 26          48
# 27          53
# 28           3
# 29           3
# 30           4
# 31          10
# 32        None
# 33        None
# 34        None
# 35        None
# 36        None
# 37        None
# 38        None
# 39        None
# 40        None
# 41        None
# 42        None
# 43        None

# %% [markdown]
# # Export File To CSV

# %%
table.to_csv('1st_Week.csv',index=False)

# %% [markdown]
# ## Upload data to DataPlatform

# %%
from dsmlibrary.datanode import DataNode

# %%
dir_raw_id = 118

# %%
datanode = DataNode()
# Out:
# Init DataNode sucessful!

# %%
datanode.upload_file(directory_id=dir_raw_id, file_path='1st_Week.csv')
# Out:
# File 1st_Week.csv alrady exists, do you want to replace y/n :  y
#   0%|          | 0.00/3.74k [00:00<?, ?B/s]
# {'id': 955,
#  'msg': 'file 1st_Week.csv create sucessful',
#  'path': 'khatcha/DSI310-21/raw/1st_Week.csv',
#  'uploaded': True}

# %% [markdown]
# ### Read stored data from DataPlatform

# %%
from dsmlibrary.datanode import DataNode
import json
from tqdm.auto import tqdm
import pandas as pd

# %%
dir_raw_id = 118
dir_process_id = 120

# %%
datanode = DataNode()
# Out:
# Init DataNode sucessful!

# %%
meta, fp = datanode.get_file(datanode.get_file_id(directory_id=dir_raw_id, name='1st_Week.csv'))
meta
# Out:
# {'owner': 'khatcha',
#  'human_size': '3.83 KB',
#  'name': '1st_Week.csv',
#  'description': 'file 1st_Week.csv',
#  'directory': 118,
#  'path': 'khatcha/DSI310-21/raw/1st_Week.csv'}

# %%
df = pd.read_csv('1st_Week.csv')
df
# Out:
#                                  Title Price_a_Night Total_Price Rating  \
# 0        ห้องส่วนตัวใน Khet Phaya Thai        1,427        5,706    5.0
# 1                ห้องส่วนตัวใน กรุงเทพ        1,383        6,231   4.87
# 2                ห้องส่วนตัวใน กรุงเทพ          720        3,080   4.99
# 3                ห้องส่วนตัวใน กรุงเทพ        1,733        7,130   4.91
# 4       ห้องส่วนตัวใน Khet Ratchathewi        1,617        7,018    5.0
# 5              ห้องส่วนตัวใน Din Daeng          739        3,754   4.98
# 6                ห้องส่วนตัวใน กรุงเทพ          779        3,347   4.95
# 7                  ห้องส่วนตัวใน พญาไท        1,291        5,364    5.0
# 8        ห้องส่วนตัวใน Khet Phaya Thai          720        3,080   4.93
# 9                ห้องส่วนตัวใน กรุงเทพ        1,618        6,670    4.9
# 10                 ห้องส่วนตัวใน พญาไท        1,240        5,158   4.95
# 11             ห้องส่วนตัวใน Din Daeng          733        3,732   4.93
# 12      ห้องส่วนตัวใน Khet Ratchathewi        1,277        5,706   4.91
# 13       ห้องพักในโรงแรมใน Ratchathewi        2,250        9,000      0
# 14               ห้องส่วนตัวใน กรุงเทพ        1,503        6,210   4.89
# 15  ห้องพักในโรงแรมใน Khet Ratchathewi        2,578       10,613   4.78
# 16               ห้องส่วนตัวใน กรุงเทพ        1,951        8,102      0
# 17       ห้องส่วนตัวใน Khet Pathum Wan          840        3,560   4.49
# 18      ห้องส่วนตัวใน Khet Ratchathewi        1,712        6,847    5.0
# 19    ห้องพักในโรงแรมใน Khet Din Daeng        1,095        4,380   4.86
# 20  ห้องพักในโรงแรมใน Khet Ratchathewi        2,350        9,400   4.89
# 21               ห้องส่วนตัวใน กรุงเทพ        1,277        5,706      0
# 22               ห้องส่วนตัวใน กรุงเทพ        1,277        5,706   4.51
# 23       ห้องส่วนตัวใน Khet Pathum Wan        1,070        4,478    5.0
# 24               ห้องส่วนตัวใน กรุงเทพ        1,826        7,304   4.73
# 25           ห้องพักในโรงแรมใน กรุงเทพ        2,578       10,613    4.8
# 26  ห้องพักในโรงแรมใน Khet Ratchathewi        2,578       10,613   4.75
# 27               ห้องส่วนตัวใน กรุงเทพ          444        1,977   4.94
# 28               ห้องส่วนตัวใน กรุงเทพ        1,277        5,706   4.33
# 29    ห้องพักในโรงแรมใน Khet Din Daeng        1,095        4,380   4.67
# 30      ห้องส่วนตัวใน Khet Ratchathewi        1,255        5,021    4.5
# 31  ห้องพักในโรงแรมใน Khet Ratchathewi        1,505        6,020    4.8
# 32       ห้องส่วนตัวใน Khet Phaya Thai        4,176       17,004   None
# 33        ห้องส่วนตัวใน Khet Din Daeng        1,568        6,270   None
# 34    ห้องพักในโรงแรมใน Khet Din Daeng        1,095        4,380   None
# 35      ห้องส่วนตัวใน Khet Ratchathewi        1,141        4,565   None
# 36      ห้องส่วนตัวใน Khet Ratchathewi        1,722        7,189   None
# 37        ห้องส่วนตัวใน Khet Din Daeng        2,090        8,360   None
# 38     ห้องในโรงแรมใน Khet Ratchathewi          944        3,777   None
# 39      ห้องส่วนตัวใน Khet Ratchathewi        3,081       12,325   None
# 40    ห้องพักในโรงแรมใน Khet Din Daeng        1,095        4,380   None
# 41      ห้องส่วนตัวใน Khet Ratchathewi        1,255        5,021   None
# 42     ห้องในโรงแรมใน Khet Ratchathewi          913        3,652   None
# 43               ห้องส่วนตัวใน กรุงเทพ        3,081       12,325   None
#
#    No_Reviewer
# 0           40
# 1           97
# 2           78
# 3          162
# 4            4
# 5           55
# 6           57
# 7           28
# 8           28
# 9          188
# 10          22
# 11         123
# 12          56
# 13           0
# 14         202
# 15          74
# 16           0
# 17          59
# 18           4
# 19          91
# 20          65
# 21           0
# 22          84
# 23           4
# 24          41
# 25          10
# 26          48
# 27          53
# 28           3
# 29           3
# 30           4
# 31          10
# 32        None
# 33        None
# 34        None
# 35        None
# 36        None
# 37        None
# 38        None
# 39        None
# 40        None
# 41        None
# 42        None
# 43        None

# %%
df.columns
# Out:
# Index(['Title', 'Price_a_Night', 'Total_Price', 'Rating', 'No_Reviewer'], dtype='object')

# %% [markdown]
# ### write DataNode to DataPlatform

# %%
datanode.write(df=df, directory=dir_process_id, name="1st_week", profiling=True, lineage=[datanode.get_file_id(directory_id=dir_raw_id, name='1st_Week.csv')])
# Out:
# {'sucess': True,
#  'file_id': 959,
#  'path': 'khatcha/DSI310-21/process/1st_week.parquet',
#  'lineage': True}
