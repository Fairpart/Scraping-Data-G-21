# %% [markdown]
# ### สร้าง var ขึ้นรองรับข้อมูล และ import ไลบารี่สำคัญ และ นำเข้า link เว็บไซต์

# %%
# Use List
Name_list = list()
Price_Per_Night_list = list()
Total_Price_list = list()
Rates_list = list()
Star_list = list()
Num_reviewer = list()
new_Num_reviewer = list()

# %%
from bs4 import BeautifulSoup
import requests

urls = ['https://th.airbnb.com/s/BTS-~-PHAYATHAI--Samsen-Nai--Phaya-Thai--Bangkok--Thailand/homes?adults=2&refinement_paths%5B%5D=%2Fhomes&tab_id=home_tab&flexible_trip_lengths%5B%5D=one_week&price_filter_input_type=0&price_filter_num_nights=4&search_type=filter_change&room_types%5B%5D=Private%20room&l2_property_type_ids%5B%5D=1&l2_property_type_ids%5B%5D=3&l2_property_type_ids%5B%5D=4&amenities%5B%5D=4&amenities%5B%5D=5&date_picker_type=calendar&source=structured_search_input_header&min_bedrooms=1&min_beds=1&min_bathrooms=1&superhost=true&checkin=2023-04-12&checkout=2023-04-16&query=BTS%20-%20PHAYATHAI%2C%20Samsen%20Nai%2C%20Phaya%20Thai%2C%20Bangkok&place_id=ChIJN6hNkx2c4jARyNY0OlyXh84&ne_lat=13.78177222948684&ne_lng=100.57352989270504&sw_lat=13.746814142447073&sw_lng=100.52343337911799&zoom=14&search_by_map=true&pagination_search=true', 
       'https://th.airbnb.com/s/BTS-~-PHAYATHAI--Samsen-Nai--Phaya-Thai--Bangkok--Thailand/homes?adults=2&refinement_paths%5B%5D=%2Fhomes&tab_id=home_tab&flexible_trip_lengths%5B%5D=one_week&price_filter_input_type=0&price_filter_num_nights=4&search_type=filter_change&room_types%5B%5D=Private%20room&l2_property_type_ids%5B%5D=1&l2_property_type_ids%5B%5D=3&l2_property_type_ids%5B%5D=4&amenities%5B%5D=4&amenities%5B%5D=5&date_picker_type=calendar&source=structured_search_input_header&min_bedrooms=1&min_beds=1&min_bathrooms=1&superhost=true&checkin=2023-04-12&checkout=2023-04-16&query=BTS%20-%20PHAYATHAI%2C%20Samsen%20Nai%2C%20Phaya%20Thai%2C%20Bangkok&place_id=ChIJN6hNkx2c4jARyNY0OlyXh84&ne_lat=13.78177222948684&ne_lng=100.57352989270504&sw_lat=13.746814142447073&sw_lng=100.52343337911799&zoom=14&search_by_map=true&federated_search_session_id=0afaa6f6-4f5b-402f-a27e-a3bee0644cc3&pagination_search=true&items_offset=20&section_offset=2', 
       'https://th.airbnb.com/s/BTS-~-PHAYATHAI--Samsen-Nai--Phaya-Thai--Bangkok--Thailand/homes?adults=2&refinement_paths%5B%5D=%2Fhomes&tab_id=home_tab&flexible_trip_lengths%5B%5D=one_week&price_filter_input_type=0&price_filter_num_nights=4&search_type=filter_change&room_types%5B%5D=Private%20room&l2_property_type_ids%5B%5D=1&l2_property_type_ids%5B%5D=3&l2_property_type_ids%5B%5D=4&amenities%5B%5D=4&amenities%5B%5D=5&date_picker_type=calendar&source=structured_search_input_header&min_bedrooms=1&min_beds=1&min_bathrooms=1&superhost=true&checkin=2023-04-12&checkout=2023-04-16&query=BTS%20-%20PHAYATHAI%2C%20Samsen%20Nai%2C%20Phaya%20Thai%2C%20Bangkok&place_id=ChIJN6hNkx2c4jARyNY0OlyXh84&ne_lat=13.78177222948684&ne_lng=100.57352989270504&sw_lat=13.746814142447073&sw_lng=100.52343337911799&zoom=14&search_by_map=true&federated_search_session_id=0afaa6f6-4f5b-402f-a27e-a3bee0644cc3&pagination_search=true&items_offset=40&section_offset=2']
for url in urls:
    req = requests.get(url,'html.parsel')
    soup = BeautifulSoup(req.text)
    
    for n in soup.find_all('div' ,{'class' : 't1jojoys dir dir-ltr'}):
        x_n = n.text
        Name_list.append(x_n)
    for p in soup.find_all('span', {'class':'_tyxjp1'}):
        x_p = p.text.split('$')[1]
        Price_Per_Night_list.append(int(x_p))
    for t in soup.find_all('div', {'class':'_tt122m'}):
        x_t = t.text.split()[1]
        x_t_1 = x_t.split('$')[1]
        Total_Price_list.append(int(x_t_1))
    for r in soup.find_all('span', {'class':'t5eq1io r4a59j5 dir dir-ltr'}):
        x_r = r.text
        Rates_list.append(x_r)
for i in Rates_list:
    rate = i.split()
    if len(rate) == 2:
        Star_list.append(rate[0])
        Num_reviewer.append(rate[1])
    else:
        Star_list.append(str(0))
        Num_reviewer.append(str(0))
for i in Num_reviewer:
    new_Num_reviewer.append(i.replace('(','').replace(')',''))

# %%
print(len(Name_list))
print(len(Price_Per_Night_list))
print(len(Total_Price_list))
print(len(Rates_list))
print(len(Star_list))
print(len(Num_reviewer))
print(len(new_Num_reviewer))
# Out:
# 44
# 44
# 44
# 44
# 44
# 44
# 44

# %% [markdown]
# ### สร้าง pandas

# %%
import pandas as pd

# %%
# Save Data to Table
# บันทึก ข้อมูล ลงตาราง #ปรับให้อยู่ในรูปคอลัมน์
table = pd.DataFrame([Name_list, Price_Per_Night_list, Total_Price_list, Star_list, new_Num_reviewer]).transpose()
#ตั้งชื่อคอลัมน์
table.columns = (['Title', 'Price Per Night in $','Total Price in $', 'Rating','Number of Reviewer'])
table
# Out:
#                                  Title Price Per Night in $ Total Price in $  \
# 0        ห้องส่วนตัวใน Khet Phaya Thai                   38              151
# 1                ห้องส่วนตัวใน กรุงเทพ                   38              172
# 2         ห้องส่วนตัวใน Khet Din Daeng                   22               87
# 3         ห้องส่วนตัวใน Khet Din Daeng                   24               96
# 4                ห้องส่วนตัวใน กรุงเทพ                   46              188
# 5       ห้องส่วนตัวใน Khet Ratchathewi                   43              186
# 6                ห้องส่วนตัวใน กรุงเทพ                   19               82
# 7                ห้องส่วนตัวใน กรุงเทพ                   21               88
# 8                  ห้องส่วนตัวใน พญาไท                   34              139
# 9              ห้องส่วนตัวใน Din Daeng                   21              103
# 10               ห้องส่วนตัวใน กรุงเทพ                   43              176
# 11  ห้องพักในโรงแรมใน Khet Ratchathewi                   68              281
# 12                 ห้องส่วนตัวใน พญาไท                   30              125
# 13               ห้องส่วนตัวใน กรุงเทพ                   40              164
# 14       ห้องส่วนตัวใน Khet Phaya Thai                   19               82
# 15      ห้องส่วนตัวใน Khet Ratchathewi                   33              132
# 16             ห้องส่วนตัวใน Din Daeng                   21              103
# 17               ห้องส่วนตัวใน กรุงเทพ                   53              220
# 18  ห้องพักในโรงแรมใน Khet Ratchathewi                   63              253
# 19               ห้องส่วนตัวใน กรุงเทพ                   12               47
# 20               ห้องส่วนตัวใน กรุงเทพ                   12               47
# 21               ห้องส่วนตัวใน กรุงเทพ                   12               53
# 22        ห้องส่วนตัวใน Khet Din Daeng                   22               89
# 23             ห้องพักในโรงแรมใน พญาไท                   89              365
# 24           ห้องพักในโรงแรมใน กรุงเทพ                   68              281
# 25       ห้องส่วนตัวใน Khet Phaya Thai                  111              450
# 26    ห้องพักในโรงแรมใน Khet Din Daeng                   29              116
# 27      ห้องส่วนตัวใน Khet Ratchathewi                   34              134
# 28  ห้องพักในโรงแรมใน Khet Ratchathewi                   62              249
# 29      ห้องส่วนตัวใน Khet Ratchathewi                   30              121
# 30               ห้องส่วนตัวใน กรุงเทพ                   48              193
# 31    ห้องพักในโรงแรมใน Khet Din Daeng                   29              116
# 32        ห้องส่วนตัวใน Khet Din Daeng                   35              138
# 33    ห้องพักในโรงแรมใน Khet Din Daeng                   29              116
# 34               ห้องส่วนตัวใน กรุงเทพ                   39              156
# 35    ห้องพักในโรงแรมใน Khet Din Daeng                   29              116
# 36        ห้องส่วนตัวใน Khet Din Daeng                   40              161
# 37      ห้องส่วนตัวใน Khet Ratchathewi                   46              191
# 38        ห้องส่วนตัวใน Khet Din Daeng                   52              206
# 39      ห้องส่วนตัวใน Khet Ratchathewi                   82              326
# 40        ห้องส่วนตัวใน Khet Din Daeng                   40              161
# 41      ห้องส่วนตัวใน Khet Ratchathewi                   33              132
# 42     ห้องในโรงแรมใน Khet Ratchathewi                   25              100
# 43               ห้องส่วนตัวใน กรุงเทพ                   82              326
#
#    Rating Number of Reviewer
# 0     5.0                 40
# 1    4.87                 97
# 2     5.0                 32
# 3    4.96                 23
# 4    4.91                157
# 5       0                  0
# 6    4.99                 74
# 7    4.94                 54
# 8     5.0                 27
# 9    4.98                 54
# 10    4.9                188
# 11      0                  0
# 12   4.95                 20
# 13   4.89                202
# 14   4.93                 28
# 15   4.49                 59
# 16   4.93                123
# 17   4.79                 71
# 18      0                  0
# 19    4.8                  5
# 20    4.8                  5
# 21   4.73                 41
# 22    5.0                  7
# 23    5.0                  4
# 24    5.0                  4
# 25      0                  0
# 26    5.0                  4
# 27   4.74                 47
# 28      0                  0
# 29      0                  0
# 30   4.51                 83
# 31      0                  0
# 32   4.94                 52
# 33      0                  0
# 34   4.72                 58
# 35      0                  0
# 36    5.0                  6
# 37   4.33                  3
# 38      0                  0
# 39   4.67                  3
# 40    5.0                  6
# 41    4.5                  4
# 42      0                  0
# 43    4.8                 10

# %%
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Title                 44 non-null     object
#  1   Price Per Night in $  44 non-null     object
#  2   Total Price in $      44 non-null     object
#  3   Rating                44 non-null     object
#  4   Number of Reviewer    44 non-null     object
# dtypes: object(5)
# memory usage: 1.8+ KB

# %%
table['Price Per Night in $'] = table['Price Per Night in $'].astype(int)

# %%
table['Total Price in $'] = table['Total Price in $'].astype(float)

# %%
table['Rating'] = table['Rating'].astype(float)

# %%
table['Number of Reviewer'] = table['Number of Reviewer'].astype(int)

# %%
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Title                 44 non-null     object
#  1   Price Per Night in $  44 non-null     int64
#  2   Total Price in $      44 non-null     float64
#  3   Rating                44 non-null     float64
#  4   Number of Reviewer    44 non-null     int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 1.8+ KB

# %%
table
# Out:
#                                  Title  Price Per Night in $  \
# 0        ห้องส่วนตัวใน Khet Phaya Thai                    38
# 1                ห้องส่วนตัวใน กรุงเทพ                    38
# 2         ห้องส่วนตัวใน Khet Din Daeng                    22
# 3         ห้องส่วนตัวใน Khet Din Daeng                    24
# 4                ห้องส่วนตัวใน กรุงเทพ                    46
# 5       ห้องส่วนตัวใน Khet Ratchathewi                    43
# 6                ห้องส่วนตัวใน กรุงเทพ                    19
# 7                ห้องส่วนตัวใน กรุงเทพ                    21
# 8                  ห้องส่วนตัวใน พญาไท                    34
# 9              ห้องส่วนตัวใน Din Daeng                    21
# 10               ห้องส่วนตัวใน กรุงเทพ                    43
# 11  ห้องพักในโรงแรมใน Khet Ratchathewi                    68
# 12                 ห้องส่วนตัวใน พญาไท                    30
# 13               ห้องส่วนตัวใน กรุงเทพ                    40
# 14       ห้องส่วนตัวใน Khet Phaya Thai                    19
# 15      ห้องส่วนตัวใน Khet Ratchathewi                    33
# 16             ห้องส่วนตัวใน Din Daeng                    21
# 17               ห้องส่วนตัวใน กรุงเทพ                    53
# 18  ห้องพักในโรงแรมใน Khet Ratchathewi                    63
# 19               ห้องส่วนตัวใน กรุงเทพ                    12
# 20               ห้องส่วนตัวใน กรุงเทพ                    12
# 21               ห้องส่วนตัวใน กรุงเทพ                    12
# 22        ห้องส่วนตัวใน Khet Din Daeng                    22
# 23             ห้องพักในโรงแรมใน พญาไท                    89
# 24           ห้องพักในโรงแรมใน กรุงเทพ                    68
# 25       ห้องส่วนตัวใน Khet Phaya Thai                   111
# 26    ห้องพักในโรงแรมใน Khet Din Daeng                    29
# 27      ห้องส่วนตัวใน Khet Ratchathewi                    34
# 28  ห้องพักในโรงแรมใน Khet Ratchathewi                    62
# 29      ห้องส่วนตัวใน Khet Ratchathewi                    30
# 30               ห้องส่วนตัวใน กรุงเทพ                    48
# 31    ห้องพักในโรงแรมใน Khet Din Daeng                    29
# 32        ห้องส่วนตัวใน Khet Din Daeng                    35
# 33    ห้องพักในโรงแรมใน Khet Din Daeng                    29
# 34               ห้องส่วนตัวใน กรุงเทพ                    39
# 35    ห้องพักในโรงแรมใน Khet Din Daeng                    29
# 36        ห้องส่วนตัวใน Khet Din Daeng                    40
# 37      ห้องส่วนตัวใน Khet Ratchathewi                    46
# 38        ห้องส่วนตัวใน Khet Din Daeng                    52
# 39      ห้องส่วนตัวใน Khet Ratchathewi                    82
# 40        ห้องส่วนตัวใน Khet Din Daeng                    40
# 41      ห้องส่วนตัวใน Khet Ratchathewi                    33
# 42     ห้องในโรงแรมใน Khet Ratchathewi                    25
# 43               ห้องส่วนตัวใน กรุงเทพ                    82
#
#     Total Price in $  Rating  Number of Reviewer
# 0              151.0    5.00                  40
# 1              172.0    4.87                  97
# 2               87.0    5.00                  32
# 3               96.0    4.96                  23
# 4              188.0    4.91                 157
# 5              186.0    0.00                   0
# 6               82.0    4.99                  74
# 7               88.0    4.94                  54
# 8              139.0    5.00                  27
# 9              103.0    4.98                  54
# 10             176.0    4.90                 188
# 11             281.0    0.00                   0
# 12             125.0    4.95                  20
# 13             164.0    4.89                 202
# 14              82.0    4.93                  28
# 15             132.0    4.49                  59
# 16             103.0    4.93                 123
# 17             220.0    4.79                  71
# 18             253.0    0.00                   0
# 19              47.0    4.80                   5
# 20              47.0    4.80                   5
# 21              53.0    4.73                  41
# 22              89.0    5.00                   7
# 23             365.0    5.00                   4
# 24             281.0    5.00                   4
# 25             450.0    0.00                   0
# 26             116.0    5.00                   4
# 27             134.0    4.74                  47
# 28             249.0    0.00                   0
# 29             121.0    0.00                   0
# 30             193.0    4.51                  83
# 31             116.0    0.00                   0
# 32             138.0    4.94                  52
# 33             116.0    0.00                   0
# 34             156.0    4.72                  58
# 35             116.0    0.00                   0
# 36             161.0    5.00                   6
# 37             191.0    4.33                   3
# 38             206.0    0.00                   0
# 39             326.0    4.67                   3
# 40             161.0    5.00                   6
# 41             132.0    4.50                   4
# 42             100.0    0.00                   0
# 43             326.0    4.80                  10

# %% [markdown]
# ## Export Pandas Data to CSV

# %%
table.to_csv('Scraping_Datas_from_AirBnB.csv')

# %% [markdown]
# ## Upload data to DataPlatform

# %%
from dsmlibrary.datanode import DataNode

# %%
dir_raw_id = 118

# %%
datanode = DataNode()
# Out:
# Init DataNode sucessful!

# %%
datanode.upload_file(directory_id=dir_raw_id, file_path='Scraping_Datas_from_AirBnB.csv')
# Out:
#   0%|          | 0.00/3.45k [00:00<?, ?B/s]
# {'id': 253,
#  'msg': 'file Scraping_Datas_from_AirBnB.csv create sucessful',
#  'path': 'khatcha/DSI310-21/raw/Scraping_Datas_from_AirBnB.csv',
#  'uploaded': True}

# %% [markdown]
# ### Read stored data from DataPlatform

# %%
from dsmlibrary.datanode import DataNode
import json
from tqdm.auto import tqdm
import pandas as pd

# %%
dir_raw_id = 118
dir_process_id = 120

# %%
datanode = DataNode()
# Out:
# Init DataNode sucessful!

# %%
meta, fp = datanode.get_file(datanode.get_file_id(directory_id=dir_raw_id, name='AirBNB_datas.json'))
meta
# Out:
# {'owner': 'khatcha',
#  'human_size': '9.57 KB',
#  'name': 'AirBNB_datas.json',
#  'description': '-',
#  'directory': 118,
#  'path': 'khatcha/DSI310-21/raw/AirBNB_datas.json'}

# %%
data = json.load(fp)
data
# Out:
# [{'Title': 'ห้องส่วนตัวใน Khet Phaya Thai',
#   'Price Per Night in $': 38,
#   'Total Price in $': 150,
#   'Rating': 5,
#   'Number of Reviewer': 40},
#  {'Title': 'ห้องส่วนตัวใน กรุงเทพ',
#   'Price Per Night in $': 38,
#   'Total Price in $': 170,
#   'Rating': 4.87,
#   'Number of Reviewer': 97},
#  {'Title': 'ห้องส่วนตัวใน Khet Din Daeng',
#   'Price Per Night in $': 22,
#   'Total Price in $': 87,
#   'Rating': 5,
#   'Number of Reviewer': 32},
#  {'Title': 'ห้องส่วนตัวใน Khet Din Daeng',
#   'Price Per Night in $': 24,
#   'Total Price in $': 95,
#   'Rating': 4.96,
#   'Number of Reviewer': 23},
#  {'Title': 'ห้องส่วนตัวใน กรุงเทพ',
#   'Price Per Night in $': 46,
#   'Total Price in $': 186,
#   'Rating': 4.91,
#   'Number of Reviewer': 157},
#  {'Title': 'ห้องส่วนตัวใน Khet Ratchathewi',
#   'Price Per Night in $': 43,
#   'Total Price in $': 184,
#   'Rating': 0,
#   'Number of Reviewer': 0},
#  {'Title': 'ห้องส่วนตัวใน กรุงเทพ',
#   'Price Per Night in $': 19,
#   'Total Price in $': 81,
#   'Rating': 4.99,
#   'Number of Reviewer': 74},
#  {'Title': 'ห้องส่วนตัวใน กรุงเทพ',
#   'Price Per Night in $': 21,
#   'Total Price in $': 88,
#   'Rating': 4.94,
#   'Number of Reviewer': 54},
#  {'Title': 'ห้องส่วนตัวใน พญาไท',
#   'Price Per Night in $': 33,
#   'Total Price in $': 138,
#   'Rating': 5,
#   'Number of Reviewer': 27},
#  {'Title': 'ห้องส่วนตัวใน Din Daeng',
#   'Price Per Night in $': 21,
#   'Total Price in $': 103,
#   'Rating': 4.98,
#   'Number of Reviewer': 54},
#  {'Title': 'ห้องส่วนตัวใน กรุงเทพ',
#   'Price Per Night in $': 43,
#   'Total Price in $': 175,
#   'Rating': 4.9,
#   'Number of Reviewer': 188},
#  {'Title': 'ห้องพักในโรงแรมใน Khet Ratchathewi',
#   'Price Per Night in $': 68,
#   'Total Price in $': 278,
#   'Rating': 0,
#   'Number of Reviewer': 0},
#  {'Title': 'ห้องส่วนตัวใน พญาไท',
#   'Price Per Night in $': 30,
#   'Total Price in $': 123,
#   'Rating': 4.95,
#   'Number of Reviewer': 20},
#  {'Title': 'ห้องส่วนตัวใน Khet Ratchathewi',
#   'Price Per Night in $': 33,
#   'Total Price in $': 131,
#   'Rating': 4.49,
#   'Number of Reviewer': 59},
#  {'Title': 'ห้องส่วนตัวใน กรุงเทพ',
#   'Price Per Night in $': 39,
#   'Total Price in $': 163,
#   'Rating': 4.89,
#   'Number of Reviewer': 202},
#  {'Title': 'ห้องส่วนตัวใน Khet Phaya Thai',
#   'Price Per Night in $': 19,
#   'Total Price in $': 81,
#   'Rating': 4.93,
#   'Number of Reviewer': 28},
#  {'Title': 'ห้องส่วนตัวใน Din Daeng',
#   'Price Per Night in $': 21,
#   'Total Price in $': 103,
#   'Rating': 4.93,
#   'Number of Reviewer': 122},
#  {'Title': 'ห้องส่วนตัวใน กรุงเทพ',
#   'Price Per Night in $': 53,
#   'Total Price in $': 219,
#   'Rating': 4.79,
#   'Number of Reviewer': 71},
#  {'Title': 'ห้องพักในโรงแรมใน Khet Ratchathewi',
#   'Price Per Night in $': 63,
#   'Total Price in $': 251,
#   'Rating': 0,
#   'Number of Reviewer': 0},
#  {'Title': 'ห้องส่วนตัวใน กรุงเทพ',
#   'Price Per Night in $': 12,
#   'Total Price in $': 53,
#   'Rating': 4.73,
#   'Number of Reviewer': 41},
#  {'Title': 'ห้องพักในโรงแรมใน Khet Ratchathewi',
#   'Price Per Night in $': 40,
#   'Total Price in $': 157,
#   'Rating': 0,
#   'Number of Reviewer': 0},
#  {'Title': 'ห้องส่วนตัวใน Khet Din Daeng',
#   'Price Per Night in $': 22,
#   'Total Price in $': 88,
#   'Rating': 5,
#   'Number of Reviewer': 7},
#  {'Title': 'ห้องพักในโรงแรมใน พญาไท',
#   'Price Per Night in $': 89,
#   'Total Price in $': 362,
#   'Rating': 5,
#   'Number of Reviewer': 4},
#  {'Title': 'ห้องพักในโรงแรมใน กรุงเทพ',
#   'Price Per Night in $': 68,
#   'Total Price in $': 278,
#   'Rating': 5,
#   'Number of Reviewer': 4},
#  {'Title': 'ห้องส่วนตัวใน Khet Phaya Thai',
#   'Price Per Night in $': 110,
#   'Total Price in $': 446,
#   'Rating': 0,
#   'Number of Reviewer': 0},
#  {'Title': 'ห้องส่วนตัวใน กรุงเทพ',
#   'Price Per Night in $': 12,
#   'Total Price in $': 46,
#   'Rating': 4.8,
#   'Number of Reviewer': 5},
#  {'Title': 'ห้องพักในโรงแรมใน Khet Din Daeng',
#   'Price Per Night in $': 29,
#   'Total Price in $': 115,
#   'Rating': 5,
#   'Number of Reviewer': 4},
#  {'Title': 'ห้องส่วนตัวใน Khet Ratchathewi',
#   'Price Per Night in $': 30,
#   'Total Price in $': 120,
#   'Rating': 0,
#   'Number of Reviewer': 0},
#  {'Title': 'ห้องพักในโรงแรมใน Khet Ratchathewi',
#   'Price Per Night in $': 62,
#   'Total Price in $': 246,
#   'Rating': 0,
#   'Number of Reviewer': 0},
#  {'Title': 'ห้องส่วนตัวใน Khet Ratchathewi',
#   'Price Per Night in $': 33,
#   'Total Price in $': 132,
#   'Rating': 4.74,
#   'Number of Reviewer': 47},
#  {'Title': 'ห้องส่วนตัวใน กรุงเทพ',
#   'Price Per Night in $': 48,
#   'Total Price in $': 192,
#   'Rating': 4.51,
#   'Number of Reviewer': 83},
#  {'Title': 'ห้องพักในโรงแรมใน Khet Din Daeng',
#   'Price Per Night in $': 29,
#   'Total Price in $': 115,
#   'Rating': 0,
#   'Number of Reviewer': 0},
#  {'Title': 'ห้องส่วนตัวใน กรุงเทพ',
#   'Price Per Night in $': 39,
#   'Total Price in $': 155,
#   'Rating': 4.72,
#   'Number of Reviewer': 58},
#  {'Title': 'ห้องพักในโรงแรมใน Khet Din Daeng',
#   'Price Per Night in $': 29,
#   'Total Price in $': 115,
#   'Rating': 0,
#   'Number of Reviewer': 0},
#  {'Title': 'ห้องส่วนตัวใน Khet Din Daeng',
#   'Price Per Night in $': 34,
#   'Total Price in $': 137,
#   'Rating': 4.94,
#   'Number of Reviewer': 52},
#  {'Title': 'ห้องพักในโรงแรมใน Khet Din Daeng',
#   'Price Per Night in $': 29,
#   'Total Price in $': 115,
#   'Rating': 0,
#   'Number of Reviewer': 0},
#  {'Title': 'ห้องส่วนตัวใน Khet Ratchathewi',
#   'Price Per Night in $': 45,
#   'Total Price in $': 188,
#   'Rating': 4.33,
#   'Number of Reviewer': 3},
#  {'Title': 'ห้องในโรงแรมใน Khet Ratchathewi',
#   'Price Per Night in $': 24,
#   'Total Price in $': 96,
#   'Rating': 0,
#   'Number of Reviewer': 0},
#  {'Title': 'ห้องส่วนตัวใน Khet Din Daeng',
#   'Price Per Night in $': 51,
#   'Total Price in $': 205,
#   'Rating': 0,
#   'Number of Reviewer': 0},
#  {'Title': 'ห้องส่วนตัวใน Khet Ratchathewi',
#   'Price Per Night in $': 81,
#   'Total Price in $': 323,
#   'Rating': 4.67,
#   'Number of Reviewer': 3},
#  {'Title': 'ห้องส่วนตัวใน Khet Din Daeng',
#   'Price Per Night in $': 40,
#   'Total Price in $': 160,
#   'Rating': 5,
#   'Number of Reviewer': 6},
#  {'Title': 'ห้องส่วนตัวใน Khet Ratchathewi',
#   'Price Per Night in $': 33,
#   'Total Price in $': 131,
#   'Rating': 4.5,
#   'Number of Reviewer': 4},
#  {'Title': 'ห้องในโรงแรมใน Khet Ratchathewi',
#   'Price Per Night in $': 24,
#   'Total Price in $': 96,
#   'Rating': 0,
#   'Number of Reviewer': 0},
#  {'Title': 'ห้องส่วนตัวใน กรุงเทพ',
#   'Price Per Night in $': 81,
#   'Total Price in $': 323,
#   'Rating': 4.8,
#   'Number of Reviewer': 10}]

# %%
df = pd.json_normalize(data)
df
# Out:
#                                  Title  Price Per Night in $  \
# 0        ห้องส่วนตัวใน Khet Phaya Thai                    38
# 1                ห้องส่วนตัวใน กรุงเทพ                    38
# 2         ห้องส่วนตัวใน Khet Din Daeng                    22
# 3         ห้องส่วนตัวใน Khet Din Daeng                    24
# 4                ห้องส่วนตัวใน กรุงเทพ                    46
# 5       ห้องส่วนตัวใน Khet Ratchathewi                    43
# 6                ห้องส่วนตัวใน กรุงเทพ                    19
# 7                ห้องส่วนตัวใน กรุงเทพ                    21
# 8                  ห้องส่วนตัวใน พญาไท                    33
# 9              ห้องส่วนตัวใน Din Daeng                    21
# 10               ห้องส่วนตัวใน กรุงเทพ                    43
# 11  ห้องพักในโรงแรมใน Khet Ratchathewi                    68
# 12                 ห้องส่วนตัวใน พญาไท                    30
# 13      ห้องส่วนตัวใน Khet Ratchathewi                    33
# 14               ห้องส่วนตัวใน กรุงเทพ                    39
# 15       ห้องส่วนตัวใน Khet Phaya Thai                    19
# 16             ห้องส่วนตัวใน Din Daeng                    21
# 17               ห้องส่วนตัวใน กรุงเทพ                    53
# 18  ห้องพักในโรงแรมใน Khet Ratchathewi                    63
# 19               ห้องส่วนตัวใน กรุงเทพ                    12
# 20  ห้องพักในโรงแรมใน Khet Ratchathewi                    40
# 21        ห้องส่วนตัวใน Khet Din Daeng                    22
# 22             ห้องพักในโรงแรมใน พญาไท                    89
# 23           ห้องพักในโรงแรมใน กรุงเทพ                    68
# 24       ห้องส่วนตัวใน Khet Phaya Thai                   110
# 25               ห้องส่วนตัวใน กรุงเทพ                    12
# 26    ห้องพักในโรงแรมใน Khet Din Daeng                    29
# 27      ห้องส่วนตัวใน Khet Ratchathewi                    30
# 28  ห้องพักในโรงแรมใน Khet Ratchathewi                    62
# 29      ห้องส่วนตัวใน Khet Ratchathewi                    33
# 30               ห้องส่วนตัวใน กรุงเทพ                    48
# 31    ห้องพักในโรงแรมใน Khet Din Daeng                    29
# 32               ห้องส่วนตัวใน กรุงเทพ                    39
# 33    ห้องพักในโรงแรมใน Khet Din Daeng                    29
# 34        ห้องส่วนตัวใน Khet Din Daeng                    34
# 35    ห้องพักในโรงแรมใน Khet Din Daeng                    29
# 36      ห้องส่วนตัวใน Khet Ratchathewi                    45
# 37     ห้องในโรงแรมใน Khet Ratchathewi                    24
# 38        ห้องส่วนตัวใน Khet Din Daeng                    51
# 39      ห้องส่วนตัวใน Khet Ratchathewi                    81
# 40        ห้องส่วนตัวใน Khet Din Daeng                    40
# 41      ห้องส่วนตัวใน Khet Ratchathewi                    33
# 42     ห้องในโรงแรมใน Khet Ratchathewi                    24
# 43               ห้องส่วนตัวใน กรุงเทพ                    81
#
#     Total Price in $  Rating  Number of Reviewer
# 0                150    5.00                  40
# 1                170    4.87                  97
# 2                 87    5.00                  32
# 3                 95    4.96                  23
# 4                186    4.91                 157
# 5                184    0.00                   0
# 6                 81    4.99                  74
# 7                 88    4.94                  54
# 8                138    5.00                  27
# 9                103    4.98                  54
# 10               175    4.90                 188
# 11               278    0.00                   0
# 12               123    4.95                  20
# 13               131    4.49                  59
# 14               163    4.89                 202
# 15                81    4.93                  28
# 16               103    4.93                 122
# 17               219    4.79                  71
# 18               251    0.00                   0
# 19                53    4.73                  41
# 20               157    0.00                   0
# 21                88    5.00                   7
# 22               362    5.00                   4
# 23               278    5.00                   4
# 24               446    0.00                   0
# 25                46    4.80                   5
# 26               115    5.00                   4
# 27               120    0.00                   0
# 28               246    0.00                   0
# 29               132    4.74                  47
# 30               192    4.51                  83
# 31               115    0.00                   0
# 32               155    4.72                  58
# 33               115    0.00                   0
# 34               137    4.94                  52
# 35               115    0.00                   0
# 36               188    4.33                   3
# 37                96    0.00                   0
# 38               205    0.00                   0
# 39               323    4.67                   3
# 40               160    5.00                   6
# 41               131    4.50                   4
# 42                96    0.00                   0
# 43               323    4.80                  10

# %% [markdown]
# ### write DataNode to DataPlatform

# %%
datanode.write(df=df, directory=dir_process_id, name="G-21_1st_data_from_AirBnB", profiling=True, lineage=[datanode.get_file_id(directory_id=dir_raw_id, name='AirBNB_datas.json')])
# Out:
# File G-21_1st_data_from_AirBnB.parquet alrady exists, do you want to replace y/n :  y
# {'sucess': True,
#  'file_id': 251,
#  'path': 'khatcha/DSI310-21/process/G-21_1st_data_from_AirBnB.parquet',
#  'lineage': True}
